# %%
import pandas as pd


df = pd.read_csv("Students_exams.csv")

# %%
df['math score'].plot(kind='density')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
df.plot(kind='density')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
df.plot(kind='density',subplots=True, layout=(2,2), sharex=False)
# Out:
# array([[<AxesSubplot: ylabel='Density'>, <AxesSubplot: ylabel='Density'>],
#        [<AxesSubplot: ylabel='Density'>, <AxesSubplot: ylabel='Density'>]],
#       dtype=object)

# %%
df = pd.read_csv("Students_exams_error.csv")

df['writing score'].plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
df = pd.read_csv("Students_exams.csv")

df['writing score'].plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
df.plot(kind='box',subplots=True, layout=(2,2), sharex=False)
# Out:
# math score          AxesSubplot(0.125,0.53;0.352273x0.35)
# reading score    AxesSubplot(0.547727,0.53;0.352273x0.35)
# writing score       AxesSubplot(0.125,0.11;0.352273x0.35)
# dtype: object
